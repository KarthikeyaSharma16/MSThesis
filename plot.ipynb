# %% [markdown]
# ## Fiat_25519_carry_mul

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use("seaborn-v0_8-pastel")

latency_in_cycles_original = np.array([80, 374])
dsp_resource_usage_original = np.array([428, 12])

latency_in_cycles = np.array([95, 85, 88, 94])
dsp_resource_usage = np.array([318, 216, 80, 50])

latency_in_cycles_v2 = np.array([83, 87, 88, 91, 93, 95, 96, 100, 105])
dsp_resource_usage_v2 = np.array([400, 314, 334, 236, 266, 190, 206, 122, 86])

latency_in_cycles_v3 = np.array([80, 86, 88, 93, 93])
dsp_resource_usage_v3 = np.array([428, 318, 152, 86, 96])

latency_in_cycles_v4 = np.array([83, 87, 88, 95])
dsp_resource_usage_v4 = np.array([240, 200, 80, 40])

latency_in_cycles_v5 = np.array([73,73,73,76,78,79,81,81,84,86,87,92])
dsp_resource_usage_v5 = np.array([396,352,328,258,292, 276,222,208,216,172,132,96])

latency_in_cycles_v6 = np.array([79, 74,72])
dsp_resource_usage_v6 = np.array([112,190,356])

latency_in_cycles_v7 = np.array([80,75,72])
dsp_resource_usage_v7 = np.array([96,144,336])

latency_pareto = np.array([80, 73, 72, 73, 72, 73, 76, 74, 75, 79, 80, 88, 94, 95, 374])
dsp_pareto = np.array([428, 396, 356, 352, 336, 328, 258, 190, 144, 112, 96, 80, 50, 40, 12])

plt.figure(figsize=(9,6))
# Plot the data points in blue
plt.plot(latency_in_cycles, dsp_resource_usage, 'bo', label = "Other possible Design Points")
plt.plot(latency_in_cycles_v2, dsp_resource_usage_v2, 'bo')
plt.plot(latency_in_cycles_v3, dsp_resource_usage_v3, 'bo')
plt.plot(latency_in_cycles_v4, dsp_resource_usage_v4, 'bo')
plt.plot(latency_in_cycles_v5, dsp_resource_usage_v5, 'bo')
plt.plot(latency_in_cycles_v6, dsp_resource_usage_v6, 'bo')
plt.plot(latency_in_cycles_v7, dsp_resource_usage_v7, 'bo')
plt.plot(latency_in_cycles_original, dsp_resource_usage_original, 'kD', label = "Extremities")
plt.plot(latency_pareto, dsp_pareto, 'r-', label = "Pareto Curve")
plt.plot(latency_pareto[1:-1], dsp_pareto[1:-1], 'g8', label = "Optimal Design Points")

plt.xlabel("Latency in Cycles (Logarithmic Scale)")
plt.ylabel("DSP Resource Usage")
plt.xscale('log')
plt.title("Pareto Curve for the function fiat_25519_carry_mul", pad = 10)
plt.grid(False)
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
